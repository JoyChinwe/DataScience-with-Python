# %%
# Task 3c Simple plot python

x= [0,1,2,3,4,5]
y = [0,1,4,9,16,25]
import matplotlib.pyplot as plt
plt.xlabel("x")
plt.ylabel("y")
plt.plot(x,y)
plt.show()

# %%
#Create a line chart for the data

Year = ["2016", "2017", "2018", "2019"]
Sales =[350, 270, 40, 600]
import matplotlib.pyplot as plt
plt.xlabel("year")
plt.ylabel("sales")
plt.plot(Year,Sales)
plt.show()

# %%
Year = ["2016", "2017", "2018", "2019"]
Sales =[350, 270, 40, 600]
import matplotlib.pyplot as plt
plt.xlabel("year")
plt.ylabel("sales")
plt.pie(Sales,labels=year)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-affcde802047> in <module>
#       4 plt.xlabel("year")
#       5 plt.ylabel("sales")
# ----> 6 plt.pie(Sales,labels=year)
#       7 plt.show()
#
# NameError: name 'year' is not defined

# %%
year = ["2016", "2017", "2018", "2019"]
sales = [350, 270, 40, 600]
import matplotlib.pyplot as plt
plt.xlabel("year") , plt.ylabel("sales")
plt.pie(sales, labels=year)	# using pie function
plt.show()

# %%
year = ["2016", "2017", "2018", "2019"]
sales = [350, 270, 40, 600]
import matplotlib.pyplot as plt
plt.xlabel("year") , plt.ylabel("sales")
plt.bar(x=year, height=sales)
plt.show()

# %%
# using pie function with colours we choose

plt.pie(sales, labels=year, colors = ['green','lightgreen', 'lightblue','blue'])
plt.show()

# %%
plt.pie(sales, labels=year, colors = ['blue','lightblue', 'lightred','red'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e4a229298fae> in <module>
# ----> 1 plt.pie(sales, labels=year, colors = ['blue','lightblue', 'lightred','red'])
#       2 plt.show()
#
# NameError: name 'plt' is not defined
